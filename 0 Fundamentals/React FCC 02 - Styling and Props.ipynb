# %% [markdown]
# # React 02
#
#
#
# **References**
# - freeCodeCamp.org (2020) Full React Course 2020 - Learn Fundamentals, Hooks, Context API, React https://www.youtube.com/watch?v=4UZrsTqkcW4&ab_channel=freeCodeCamp.org

# %% [markdown]
# ## 1) React Syntax
# - `Prettier` code formatter

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''<style> pre { white-space: pre-wrap; }</style>'''))
get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# ### `index.js`
# Start from scratch.
#
# This file is the entry point to your app.
# - `import ReactDom from 'react-dom'`: helps inject HTML components into `index.js`
# - `ReactDom`
#   - `.render(<HTML component>)`: grabs HTML component and displays on your web page.
#
# <br>
#
# 📂React-App-in-production
# ├── 📂build
# ├── 📂public
# ├── 📂src
# │ㅤㅤ└── index.js  (write from scratch!)
# ├── 📃 .gitignore
# ├── 📃 package-lock.json
# └── 📃 package.json

# %%
from IPython.display import display, Javascript
# Out:
# <style> pre { white-space: pre-wrap; }</style>

# %%
Javascript("""
    function Greeting() {
    // From React component, we want to return HTML.
    // a custom component function.
    return <h4>Welcome to coding Forest! This is my first component!</h4>;
    }

    ReactDom.render(<Greeting/>, document.getElementById('root'));
""")
# Out:
# <style> pre { white-space: pre-wrap; }</style>
# <PIL.Image.Image image mode=RGB size=454x96 at 0x7F70113E1390>

# %% [markdown]
# 2) JSX
# Rules
# - must return single element
# - `div`, `section`, `article`, or `Fragment`
# - use camelCase for html attributes
# - className instead of class
# - close every element
# - formatting

# %% [markdown]
# ### JSX syntax
# All four methods below work fine.

# %% [markdown]
# #### Method 1

# %%
Javascript(""" 

function Greeting() {
  // From React component, we want to return HTML.
  return <h4>Welcome to coding Forest! This is my first component!</h4>;
}
""")

# %% [markdown]
# #### Method 2

# %%
Javascript(""" 

const Greeting = () => {
  return React.createElement('h1', {}, 'Welcome to Coding Forest');
};
*/
""")

# %% [markdown]
# #### Method 3

# %%
Javascript(""" 

function Greeting() {
  return (
    <div>
      <h1>Welcome to Coding Forest</h1>
      <p>This is my first React project! Have fun!</p>
    </div>
  );
}
""")

# %% [markdown]
# #### Method 4 - Nested components

# %%
Javascript(""" 
function Greeting() {
  return (
    <div className="">
      <div>
        <Person/>
        <Message/>
      </div>
    </div>
  );
}

const Person = () => <h2>Forest that codes</h2>;
const Message = () => {
  return <div><h1>Welcome to Coding Forest</h1>
  <p>This is my first React project! Have fun!</p>
  </div>;
}
""")

# %% [markdown]
# ## 2) CSS
# Unlike importing React-related modules, provide full path for CSS-related imports.
# - `import './'  `

# %%
* {
  margin: 0;
  padding: 0;
  box=sizing: border-box;
}

body {
  font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Oxygen,
    Ubuntu, Cantarell, "Open Sans", "Helvetica Neue", sans-serif;
  background: #f1f5f8;
  color: #222;
}

# %% [markdown]
# ### Styling

# %%
# index.css
.book h4 {
    color: '#617d98';
    fontSize:'0.75rem';
    letter-spacing: 0.1rem;
    marginTop:'0.25rem';
}

# %%
Javascript(""" 

const Title = () => <h3>I Love you to the Moon and Back</h3>;
// will render the same effect.
const Author = () => <h4 style={{ color: '#617d98', fontSize:'0.75rem', letter-spacing: 0.1rem, marginTop:'0.25rem'; }}>Amelia Hepworth</h4>; 
const Image = () => (
  <img
    src="https://images-na.ssl-images-amazon.com/images/I/517h-u1AQlL._SX218_BO1,204,203,200_QL40_FMwebp_.jpg"
    alt="book cover"
  />
)

""")
# Out:
# <style> pre { white-space: pre-wrap; }</style>
# <PIL.Image.Image image mode=RGB size=392x374 at 0x7F7001F48CD0>

# %% [markdown]
# ## 3) Props (Constructors)
# Let's build object constructors (create components with variable attributes.)
#
# Compare the following:

# %%
# Static invariable constructor with hard-coded attribute values.
Javascript(""" 

function Booklist() {
  return <section className='booklist'>
      <Book/>
      <Book/>
    </section>
  }

const Book = () => {
  return (<article className='book'>
      <Image />
      <Title />     // inserted here
      <Author />    // inserted here
    </article>)
}

const Title = () => <h3>I Love you to the Moon and Back</h3>;  // hard-coded
const Author = () => <h4>Amelia Hepworth</h4>;                 // hard-coded
const Image = () => (
  <img
    src="https://images-na.ssl-images-amazon.com/images/I/517h-u1AQlL._SX218_BO1,204,203,200_QL40_FMwebp_.jpg"
    alt="book cover"
  />
)

""")

# %%
# Syntax for variable constructor

Javascript(""" 

const Book = () => {
  const title = "I Love you to the Moon and Back"  
  const author = "Amelia Hepworth"
  return (<article className='book'>
      <Image />
      <h1>{title}</h1>      // soft coded; allows for a more flexible value control. 
      <h4>{author}</h4>     // soft coded
    </article>)
}

const Image = () => (
  <img
    src="https://images-na.ssl-images-amazon.com/images/I/517h-u1AQlL._SX218_BO1,204,203,200_QL40_FMwebp_.jpg"
    alt="book cover"
  />
)

""")
# Out:
# <style> pre { white-space: pre-wrap; }</style>
# <PIL.Image.Image image mode=RGB size=858x381 at 0x7F7001F65150>

# %% [markdown]
# ### 3-1. Instances form `Props`
#
# (**Instances from a constructor**)
#
# Let's re-write the code to allow to create multiple instances out of the constructor.

# %%
# Compare the following: 
# a variable with hard-coded values.
Javascript("""

const Book = () => {
  const title = "I Love you to the Moon and Back"
  const author = "Amelia Hepworth"
  return (<article className='book'>
      <Image />
      <h1>{title}</h1>
      <h4>{author.toUpperCase()}</h4>
      <p>{ 5354 + 22}</p>
    </article>)
}

const Image = () => (
  <img
    src="https://images-na.ssl-images-amazon.com/images/I/517h-u1AQlL._SX218_BO1,204,203,200_QL40_FMwebp_.jpg"
    alt="book cover"
  />
)

""")

# %%
# Use the power of JavaScript. 
# reorganise the code into 1) constructor, then 2) instances (vars), then call them in the Booklist.

Javascript("""

// constructor - Book
const Book = (props) => {
  console.log(props);
  return (
    <article className='book'>
      <img src={props.img} alt='' /> 
      <h1>{props.title}</h1>
      <h4>{props.author}</h4>
    </article>
  );
}

// setup vars
const Book1 = {
  img: "https://images-na.ssl-images-amazon.com/images/I/517h-u1AQlL._SX218_BO1,204,203,200_QL40_FMwebp_.jpg",
  title: 'I Love you to the Moon and Back',
  author: "Amelia Hepworth"
}

function Booklist() {
  return <section className='booklist'>
      <Book img={Book1.img} title={Book1.title} author={Book1.author}/>
      <Book img={Book2.img} title={Book2.title} author={Book2.author}/>
      ...
    </section>
  }

""")

# %% [markdown]
# ### 3-2. `Prop` destructuring

# %%
# Before destructuring
Javascript("""

const Book = (props) => {
  return (
    <article className='book'>
      <img src={props.img} alt='' /> 
      <h1>{props.title}</h1>
      <h4>{props.author}</h4>
    </article>
  );
}

""")

# %% [markdown]
# ##### Destructuring syntax 1

# %%
# Destructured props
Javascript("""

// constructor - Book
const Book = (props) => {
  const {img, title, author} = props;   // destructuring
  return (
    <article className='book'>
      <img src={img} alt='' /> 
      <h1>{title}</h1>
      <h4>{author}</h4>
    </article>
  );
}

""")

# %% [markdown]
# ##### Destructuring syntax 2

# %%
Javascript("""

const Book = ({ img, title, author}) => {   // destructuring
  return (
    <article className='book'>
      <img src={img} alt='' /> 
      <h1>{title}</h1>
      <h4>{author}</h4>
    </article>
  );
}

""")

# %% [markdown]
# #### 3-3. Children

# %%
Javascript("""

const Book = ({ img, title, author, link, children}) => {
  return (
    <article className='book'>
      <a href={link} rel="noreferrer" target="_blank"><img src={img} alt='' /></a>
      <h1>{title}</h1>
      <h4>{author}</h4>
      {children}         // children here. 
    </article>
  );
}


function Booklist() {
  return <section className='booklist'>
      <Book img={Book1.img} title={Book1.title} author={Book1.author}/>
        ...
      <Book img={Book8.img} title={Book8.title} author={Book8.author}>
        <p>Julia Donaldson is a top selling author of children’s books with over 65 million books sold worldwide...
        </p>
      </Book>
    </section>
  }

""")

# %% [markdown]
# ##### css: `align-items: start`
# Each card has a custom height according to its content.

# %%
@media screen and (min-width: 768px) {
  .booklist {
    grid-template-columns: repeat(3, 1fr);
    align-items: start;  # each card has a custom height according to its content.
  }
}
# Out:
# <style> pre { white-space: pre-wrap; }</style>
# <PIL.Image.Image image mode=RGB size=775x956 at 0x7F7001FB1D90>

# %% [markdown]
# ## Extensions
#
# 1) React Developr Tools (on Chrome)
# https://chrome.google.com/webstore/detail/react-developer-tools/fmkadmapgofadopljbjfkapdkoienihi/related?hl=en
